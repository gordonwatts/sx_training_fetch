# %% [markdown]
# # Fetch
#
# Some dirt code to fetch data from UChicago that we need for training. The plan is to get this working and then turn it into something "production"
#
# NOTE: for now we need to use an older version of `uproot` and `awkward` - due to an internal bug.

# %% [markdown]
# ## Imports

# %%
from func_adl_servicex_xaodr21 import atlas_release
from func_adl_servicex_xaodr21 import SXDSAtlasxAODR21

print(f'Using release {atlas_release}')
# Out:
# Using release 21.2.231

# %% [markdown]
# ## Datasets
#
# The datasets we can find right now... Here are a few lists. Here is what we are using officially for the analysis.
#
# ```
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Name                                                                                                                              ┃ Files ┃ Tag   ┃ Cache      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━┩
# │ mc16_13TeV.311421.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS50.deriv.DAOD_EXOT15.e7357_e5984_s3234_r10201_r10210_p4696         │ 10    │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.311421.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS50.deriv.DAOD_EXOT15.e7357_e5984_s3234_r10724_r10726_p4696         │ 11    │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.311421.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS50.deriv.DAOD_EXOT15.e7357_e5984_s3234_r9364_r9315_p4696           │ 8     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.311421.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS50.deriv.DAOD_EXOT15.e7357_s3234_r10201_p4696                      │ 10    │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.311421.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS50.deriv.DAOD_EXOT15.e7357_s3234_r10724_p4696                      │ 11    │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.311421.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS50.deriv.DAOD_EXOT15.e7357_s3234_r9364_p4696                       │ 8     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.311422.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_ltlow.deriv.DAOD_EXOT15.e7357_e5984_s3234_r10201_r10210_p4696  │ 10    │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.311422.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_ltlow.deriv.DAOD_EXOT15.e7357_e5984_s3234_r10724_r10726_p4696  │ 11    │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.311422.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_ltlow.deriv.DAOD_EXOT15.e7357_e5984_s3234_r9364_r9315_p4696    │ 8     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.311422.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_ltlow.deriv.DAOD_EXOT15.e7357_s3234_r10201_p4696               │ 10    │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.311422.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_ltlow.deriv.DAOD_EXOT15.e7357_s3234_r10724_p4696               │ 11    │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.311422.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_ltlow.deriv.DAOD_EXOT15.e7357_s3234_r9364_p4696                │ 8     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.311423.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_lthigh.deriv.DAOD_EXOT15.e7357_e5984_s3234_r10201_r10210_p4696 │ 5     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.311423.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_lthigh.deriv.DAOD_EXOT15.e7357_e5984_s3234_r10724_r10726_p4696 │ 6     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.311423.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_lthigh.deriv.DAOD_EXOT15.e7357_e5984_s3234_r9364_r9315_p4696   │ 4     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.311423.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_lthigh.deriv.DAOD_EXOT15.e7357_s3234_r10201_p4696              │ 5     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.311423.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_lthigh.deriv.DAOD_EXOT15.e7357_s3234_r10724_p4696              │ 6     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.311423.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS150_lthigh.deriv.DAOD_EXOT15.e7357_s3234_r9364_p4696               │ 4     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_e5984_s3234_r10201_r10210_p4696        │ 18    │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_e5984_s3234_r10724_r10726_p4696        │ 21    │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_e5984_s3234_r12291_r12294_p4905        │ 13    │       │ 21.2.134.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_e5984_s3234_r12726_r12294_p4905        │ 13    │       │ 21.2.134.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_e5984_s3234_r12727_r12294_p4905        │ 13    │       │ 21.2.134.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_e5984_s3234_r9364_r9315_p4696          │ 14    │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_s3234_r10201_p4696                     │ 18    │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_s3234_r10724_p4696                     │ 21    │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_s3234_r12291_p4905                     │ 13    │       │ 21.2.134.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_s3234_r12726_p4905                     │ 13    │       │ 21.2.134.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_s3234_r12727_p4905                     │ 13    │       │ 21.2.134.0 │
# │ mc16_13TeV.311424.MGPy8EG_A14NNPDF23_NNPDF31ME_HSS_LLP_mH600_mS275.deriv.DAOD_EXOT15.e7357_s3234_r9364_p4696                      │ 14    │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501823.MGPy8EG_A14N23LO_HZZd_125_5_600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10201_r10210_p4696                         │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501823.MGPy8EG_A14N23LO_HZZd_125_5_600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10724_r10726_p4696                         │ 2     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501823.MGPy8EG_A14N23LO_HZZd_125_5_600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r9364_r9315_p4696                           │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501823.MGPy8EG_A14N23LO_HZZd_125_5_600.deriv.DAOD_EXOT15.e8253_s3126_r10201_p4696                                      │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501823.MGPy8EG_A14N23LO_HZZd_125_5_600.deriv.DAOD_EXOT15.e8253_s3126_r10724_p4696                                      │ 2     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501823.MGPy8EG_A14N23LO_HZZd_125_5_600.deriv.DAOD_EXOT15.e8253_s3126_r9364_p4696                                       │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501824.MGPy8EG_A14N23LO_HZZd_125_15_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10201_r10210_p4696                       │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501824.MGPy8EG_A14N23LO_HZZd_125_15_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10724_r10726_p4696                       │ 2     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501824.MGPy8EG_A14N23LO_HZZd_125_15_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r9364_r9315_p4696                         │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501824.MGPy8EG_A14N23LO_HZZd_125_15_1600.deriv.DAOD_EXOT15.e8253_s3126_r10201_p4696                                    │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501824.MGPy8EG_A14N23LO_HZZd_125_15_1600.deriv.DAOD_EXOT15.e8253_s3126_r10724_p4696                                    │ 2     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501824.MGPy8EG_A14N23LO_HZZd_125_15_1600.deriv.DAOD_EXOT15.e8253_s3126_r9364_p4696                                     │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501825.MGPy8EG_A14N23LO_HZZd_250_50_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10201_r10210_p4696                       │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501825.MGPy8EG_A14N23LO_HZZd_250_50_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10724_r10726_p4696                       │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501825.MGPy8EG_A14N23LO_HZZd_250_50_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r9364_r9315_p4696                         │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501825.MGPy8EG_A14N23LO_HZZd_250_50_1600.deriv.DAOD_EXOT15.e8253_s3126_r10201_p4696                                    │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501825.MGPy8EG_A14N23LO_HZZd_250_50_1600.deriv.DAOD_EXOT15.e8253_s3126_r10724_p4696                                    │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501825.MGPy8EG_A14N23LO_HZZd_250_50_1600.deriv.DAOD_EXOT15.e8253_s3126_r9364_p4696                                     │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501827.MGPy8EG_A14N23LO_HZZd_400_100_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10201_r10210_p4696                      │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501827.MGPy8EG_A14N23LO_HZZd_400_100_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10724_r10726_p4696                      │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501827.MGPy8EG_A14N23LO_HZZd_400_100_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r9364_r9315_p4696                        │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501827.MGPy8EG_A14N23LO_HZZd_400_100_1600.deriv.DAOD_EXOT15.e8253_s3126_r10201_p4696                                   │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501827.MGPy8EG_A14N23LO_HZZd_400_100_1600.deriv.DAOD_EXOT15.e8253_s3126_r10724_p4696                                   │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501827.MGPy8EG_A14N23LO_HZZd_400_100_1600.deriv.DAOD_EXOT15.e8253_s3126_r9364_p4696                                    │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501829.MGPy8EG_A14N23LO_HZZd_600_150_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10201_r10210_p4696                      │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501829.MGPy8EG_A14N23LO_HZZd_600_150_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10724_r10726_p4696                      │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501829.MGPy8EG_A14N23LO_HZZd_600_150_1600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r9364_r9315_p4696                        │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501829.MGPy8EG_A14N23LO_HZZd_600_150_1600.deriv.DAOD_EXOT15.e8253_s3126_r10201_p4696                                   │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501829.MGPy8EG_A14N23LO_HZZd_600_150_1600.deriv.DAOD_EXOT15.e8253_s3126_r10724_p4696                                   │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501829.MGPy8EG_A14N23LO_HZZd_600_150_1600.deriv.DAOD_EXOT15.e8253_s3126_r9364_p4696                                    │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501830.MGPy8EG_A14N23LO_HZZd_600_400_4600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10201_r10210_p4696                      │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501830.MGPy8EG_A14N23LO_HZZd_600_400_4600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10724_r10726_p4696                      │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501830.MGPy8EG_A14N23LO_HZZd_600_400_4600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r9364_r9315_p4696                        │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501830.MGPy8EG_A14N23LO_HZZd_600_400_4600.deriv.DAOD_EXOT15.e8253_s3126_r10201_p4696                                   │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501830.MGPy8EG_A14N23LO_HZZd_600_400_4600.deriv.DAOD_EXOT15.e8253_s3126_r10724_p4696                                   │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501830.MGPy8EG_A14N23LO_HZZd_600_400_4600.deriv.DAOD_EXOT15.e8253_s3126_r9364_p4696                                    │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501832.MGPy8EG_A14N23LO_HZZd_600_150_4000.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10201_r10210_p4696                      │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501832.MGPy8EG_A14N23LO_HZZd_600_150_4000.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10724_r10726_p4696                      │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501832.MGPy8EG_A14N23LO_HZZd_600_150_4000.deriv.DAOD_EXOT15.e8253_e7400_s3126_r9364_r9315_p4696                        │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501832.MGPy8EG_A14N23LO_HZZd_600_150_4000.deriv.DAOD_EXOT15.e8253_s3126_r10201_p4696                                   │ 2     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501832.MGPy8EG_A14N23LO_HZZd_600_150_4000.deriv.DAOD_EXOT15.e8253_s3126_r10724_p4696                                   │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501832.MGPy8EG_A14N23LO_HZZd_600_150_4000.deriv.DAOD_EXOT15.e8253_s3126_r9364_p4696                                    │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501833.MGPy8EG_A14N23LO_GG_ZG_700_150_600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10201_r10210_p4696                      │ 5     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501833.MGPy8EG_A14N23LO_GG_ZG_700_150_600.deriv.DAOD_EXOT15.e8253_e7400_s3126_r9364_r9315_p4696                        │ 3     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501833.MGPy8EG_A14N23LO_GG_ZG_700_150_600.deriv.DAOD_EXOT15.e8253_s3126_r10201_p4696                                   │ 5     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501833.MGPy8EG_A14N23LO_GG_ZG_700_150_600.deriv.DAOD_EXOT15.e8253_s3126_r9364_p4696                                    │ 3     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501838.MGPy8EG_A14N23LO_GG_ZG_1100_1000_6000.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10201_r10210_p4696                   │ 3     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501838.MGPy8EG_A14N23LO_GG_ZG_1100_1000_6000.deriv.DAOD_EXOT15.e8253_e7400_s3126_r10724_r10726_p4696                   │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501838.MGPy8EG_A14N23LO_GG_ZG_1100_1000_6000.deriv.DAOD_EXOT15.e8253_e7400_s3126_r9364_r9315_p4696                     │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.501838.MGPy8EG_A14N23LO_GG_ZG_1100_1000_6000.deriv.DAOD_EXOT15.e8253_s3126_r10201_p4696                                │ 3     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.501838.MGPy8EG_A14N23LO_GG_ZG_1100_1000_6000.deriv.DAOD_EXOT15.e8253_s3126_r10724_p4696                                │ 3     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.501838.MGPy8EG_A14N23LO_GG_ZG_1100_1000_6000.deriv.DAOD_EXOT15.e8253_s3126_r9364_p4696                                 │ 1     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.507682.MGPy8EG_A14N23LO_HZZd_125_16_1600.deriv.DAOD_EXOT15.e8307_e7400_s3126_r10201_r10210_p4696                       │ 4     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.507682.MGPy8EG_A14N23LO_HZZd_125_16_1600.deriv.DAOD_EXOT15.e8307_e7400_s3126_r10724_r10726_p4696                       │ 4     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.507682.MGPy8EG_A14N23LO_HZZd_125_16_1600.deriv.DAOD_EXOT15.e8307_e7400_s3126_r9364_r9315_p4696                         │ 2     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.507682.MGPy8EG_A14N23LO_HZZd_125_16_1600.deriv.DAOD_EXOT15.e8307_s3126_r10201_p4696                                    │ 4     │ MC16d │ 21.2.128.0 │
# │ mc16_13TeV.507682.MGPy8EG_A14N23LO_HZZd_125_16_1600.deriv.DAOD_EXOT15.e8307_s3126_r10724_p4696                                    │ 4     │ MC16e │ 21.2.128.0 │
# │ mc16_13TeV.507682.MGPy8EG_A14N23LO_HZZd_125_16_1600.deriv.DAOD_EXOT15.e8307_s3126_r9364_p4696                                     │ 2     │ MC16a │ 21.2.128.0 │
# │ mc16_13TeV.512030.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10201_r10210_p5037              │ 4     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512030.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10724_r10726_p5037              │ 6     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512030.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_e7400_s3126_r9364_r9315_p5037                │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512030.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_s3126_r10201_p5037                           │ 4     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512030.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_s3126_r10724_p5037                           │ 6     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512030.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_s3126_r9364_p5037                            │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512031.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10201_r10210_p5037            │ 4     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512031.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10724_r10726_p5037            │ 4     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512031.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r9364_r9315_p5037              │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512031.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_s3126_r10201_p5037                         │ 4     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512031.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_s3126_r10724_p5037                         │ 4     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512031.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_s3126_r9364_p5037                          │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512032.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10201_r10210_p5037            │ 2     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512032.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10724_r10726_p5037            │ 2     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512032.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r9364_r9315_p5037              │ 1     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512032.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_s3126_r10201_p5037                         │ 2     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512032.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_s3126_r10724_p5037                         │ 2     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512032.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_s3126_r9364_p5037                          │ 1     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512033.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10201_r10210_p5037            │ 6     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512033.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10724_r10726_p5037            │ 4     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512033.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r9364_r9315_p5037              │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512033.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_s3126_r10201_p5037                         │ 6     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512033.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_s3126_r10724_p5037                         │ 4     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512033.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_s3126_r9364_p5037                          │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512051.MGPy8EG_A14NNPDF23_WH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10201_r10210_p5037              │ 5     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512051.MGPy8EG_A14NNPDF23_WH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10724_r10726_p5037              │ 4     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512051.MGPy8EG_A14NNPDF23_WH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_e7400_s3126_r9364_r9315_p5037                │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512051.MGPy8EG_A14NNPDF23_WH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_s3126_r10201_p5037                           │ 5     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512051.MGPy8EG_A14NNPDF23_WH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_s3126_r10724_p5037                           │ 4     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512051.MGPy8EG_A14NNPDF23_WH_LLP_H600_S50_ctau400.deriv.DAOD_EXOT15.e8412_s3126_r9364_p5037                            │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512052.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10201_r10210_p5037            │ 4     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512052.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10724_r10726_p5037            │ 4     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512052.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r9364_r9315_p5037              │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512052.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_s3126_r10201_p5037                         │ 4     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512052.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_s3126_r10724_p5037                         │ 4     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512052.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau1500.deriv.DAOD_EXOT15.e8412_s3126_r9364_p5037                          │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512053.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10201_r10210_p5037            │ 2     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512053.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10724_r10726_p5037            │ 2     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512053.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r9364_r9315_p5037              │ 1     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512053.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_s3126_r10201_p5037                         │ 2     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512053.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_s3126_r10724_p5037                         │ 2     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512053.MGPy8EG_A14NNPDF23_WH_LLP_H600_S150_ctau3500.deriv.DAOD_EXOT15.e8412_s3126_r9364_p5037                          │ 1     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512054.MGPy8EG_A14NNPDF23_WH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10201_r10210_p5037            │ 4     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512054.MGPy8EG_A14NNPDF23_WH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10724_r10726_p5037            │ 3     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512054.MGPy8EG_A14NNPDF23_WH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r9364_r9315_p5037              │ 2     │ MC16a │ 21.2.139.0 │
# │ mc16_13TeV.512054.MGPy8EG_A14NNPDF23_WH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_s3126_r10201_p5037                         │ 4     │ MC16d │ 21.2.139.0 │
# │ mc16_13TeV.512054.MGPy8EG_A14NNPDF23_WH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_s3126_r10724_p5037                         │ 3     │ MC16e │ 21.2.139.0 │
# │ mc16_13TeV.512054.MGPy8EG_A14NNPDF23_WH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_s3126_r9364_p5037                          │ 2     │ MC16a │ 21.2.139.0 │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴───────┴───────┴────────────┘
#
# A quick look at other scoopes, like `mc20_13TeV` and `mc23_13p6TeV` shows that there are no other samples. This is in.
# ```

# %%
# rucio_ds = "mc16_13TeV.512033.MGPy8EG_A14NNPDF23_ZH_LLP_H600_S275_ctau2500.deriv.DAOD_EXOT15.e8412_e7400_s3126_r10201_r10210_p5037"
# ds = SXDSAtlasxAODR21(rucio_ds, backend='atlasr21')

from func_adl_servicex import SXLocalxAOD
from func_adl_servicex_xaodr21.event_collection import Event
rucio_file = r"C:\Users\gordo\Code\atlas\data\DAOD_EXOT15.26710706._000001.pool.root.1"
ds = SXLocalxAOD(rucio_file, item_type=Event, docker_tag='21.2.231')
# Out:
# Found backend type matching "xaod". Matching by type is deprecated. Please switch to using the "name" keyword in your servicex.yaml file.
# Found backend type matching "xaod". Matching by type is deprecated. Please switch to using the "name" keyword in your servicex.yaml file.

# %% [markdown]
# ## Event level information
#
# This is the basic info for run and event number

# %%
event_info_query = ds.Select(
    lambda e: {
        "run_number": e.EventInfo("EventInfo").runNumber(),
        "event_number": e.EventInfo("EventInfo").eventNumber(),
    }
)

event_info = event_info_query.as_awkward().value()

# %%
event_info.compute()
# Out:
# <Array [{run_number: 300000, ...}, ..., {...}] type='10000 * {run_number: u...'>

# %% [markdown]
# ## Jet PT's
#
# Lets go after the simple jet variables we need.

# %%
jet_kinematics_query = (
    ds.SelectMany(lambda e: e.Jets(collection="AntiKt4EMTopoJets", calibrate=False))
    .Where(lambda j: (j.pt() / 1000) > 30)
    .Select(lambda j: {"jet_pt": j.pt() / 1000.0, "jet_eta": j.eta(), "jet_phi": j.phi()})
)
jet_kinematics = jet_kinematics_query.AsAwkwardArray().value()
# Out:
# WARNING:root:Fetched the default calibration configuration for a query. It should have been intentionally configured - using configuration for data format PHYS

# %%
jet_kinematics.compute()
# Out:
# <Array [{jet_pt: 209, jet_eta: ..., ...}, ...] type='30826 * {jet_pt: float...'>

# %% [markdown]
# ## Calorimeter TopoClusters
#
# In the code this is mostly referred to as _jet constituents_. The C++ code that fetches this is a [bit complex](https://gitlab.cern.ch/atlas-phys-exotics-llp-mscrid/fullrun2analysis/DiVertAnalysisR21/-/blob/master/DiVertAnalysis/Root/RegionVarCalculator_calRatio.cxx#L393) and I think more convoluted that it need be.

# %%
from func_adl_servicex_xaodr21.calosampling import CaloSampling
clusters_query = (
    ds.Select(lambda e: e.CaloClusters("egammaClusters"))
    .Select(lambda e: {
        "pt": e.Select(lambda cluster: cluster.pt() / 1000.0),
        "eta": e.Select(lambda cluster: cluster.eta() / 1000.0),
        "phi": e.Select(lambda cluster: cluster.phi() / 1000.0),
        # TODO: Check the layers below here are right!!
        # TODO: use a dictionary, and why do we sum in the C++? Need a hardware map...
        "preB": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.PreSamplerB)),
        "preE": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.PreSamplerE)),
        "l1ecal": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.EMB1)),
        "l2ecal": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.EMB2)),
        "l3ecal": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.EMB3)),
        "l1ecalE": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.EME1)),
        "l2ecalE": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.EME2)),
        "l3ecalE": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.EME3)),
        "l0hcal": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.HEC0)),
        "l1hcal": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.HEC1)),
        "l2hcal": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.HEC2)),
        "l3hcal": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.HEC3)),
        "l0tbar": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.TileBar0)),
        "l1tbar": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.TileBar1)),
        "l2tbar": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.TileBar2)),
        "l0tbarG": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.TileGap1)),
        "l1tbarG": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.TileGap2)),
        "l2tbarG": e.Select(lambda cluster: cluster.eSample(CaloSampling.CaloSample.TileGap3)),
    }
    ))

clusters = clusters_query.AsAwkwardArray().value()
# Out:
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling
# WARNING:func_adl.type_based_replacement:Unknown type for name CaloSampling

# %%
clusters.compute()
# Out:
# <Array [{pt: [61.7, ...], eta: ..., ...}, ...] type='10000 * {pt: var * flo...'>

# %%
clusters.compute().l1ecal
# Out:
# <Array [[2.16e+04, 1.92e+04, ..., 0, 0], ...] type='10000 * var * float32'>

# %% [markdown]
# ## Tracks
#
# Lets do all the tracks here

# %%
pv_query = (
    ds
    .Select(lambda e: e.Vertices("PrimaryVertices"))
    .Select(lambda vtx: vtx.First())
)

track_query = (
    pv_query
    .Select(lambda v: v.trackParticleLinks().Where(lambda t: t.pt() > 500.0))
    .Select(lambda tracks: {
        "pt": tracks.Select(lambda t: t.pt()),
        "eta": tracks.Select(lambda t: t.eta()),
        "phi": tracks.Select(lambda t: t.phi()),
    })
)

tracks= track_query.AsAwkwardArray().value()
# Out:
# ERROR:func_adl_xAOD.common.local_dataset:Docker image and tag: atlas/analysisbase:21.2.231
# ERROR:func_adl_xAOD.common.local_dataset:Docker Output:
# ERROR:func_adl_xAOD.common.local_dataset:  Configured GCC from: /opt/lcg/gcc/8.3.0-cebb0/x86_64-centos7/bin/gcc
# ERROR:func_adl_xAOD.common.local_dataset:  Configured AnalysisBase from: /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt
# ERROR:func_adl_xAOD.common.local_dataset:  -- The C compiler identification is GNU 8.3.0
# ERROR:func_adl_xAOD.common.local_dataset:  -- The CXX compiler identification is GNU 8.3.0
# ERROR:func_adl_xAOD.common.local_dataset:  -- Detecting C compiler ABI info
# ERROR:func_adl_xAOD.common.local_dataset:  -- Detecting C compiler ABI info - done
# ERROR:func_adl_xAOD.common.local_dataset:  -- Check for working C compiler: /opt/lcg/gcc/8.3.0-cebb0/x86_64-centos7/bin/gcc - skipped
# ERROR:func_adl_xAOD.common.local_dataset:  -- Detecting C compile features
# ERROR:func_adl_xAOD.common.local_dataset:  -- Detecting C compile features - done
# ERROR:func_adl_xAOD.common.local_dataset:  -- Detecting CXX compiler ABI info
# ERROR:func_adl_xAOD.common.local_dataset:  -- Detecting CXX compiler ABI info - done
# ERROR:func_adl_xAOD.common.local_dataset:  -- Check for working CXX compiler: /opt/lcg/gcc/8.3.0-cebb0/x86_64-centos7/bin/g++ - skipped
# ERROR:func_adl_xAOD.common.local_dataset:  -- Detecting CXX compile features
# ERROR:func_adl_xAOD.common.local_dataset:  -- Detecting CXX compile features - done
# ERROR:func_adl_xAOD.common.local_dataset:  -- Found AnalysisBase: /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt (version: 21.2.231)
# ERROR:func_adl_xAOD.common.local_dataset:  -- Found AnalysisBaseExternals: /usr/AnalysisBaseExternals/21.2.231/InstallArea/x86_64-centos7-gcc8-opt (version: 21.2.231)
# ERROR:func_adl_xAOD.common.local_dataset:  -- Setting ATLAS specific build flags
# ERROR:func_adl_xAOD.common.local_dataset:  -- checker_gccplugins library not found
# ERROR:func_adl_xAOD.common.local_dataset:  -- Package(s) in AnalysisBaseExternals: 22
# ERROR:func_adl_xAOD.common.local_dataset:  -- Using the LCG modules without setting up a release
# ERROR:func_adl_xAOD.common.local_dataset:  -- Package(s) in AnalysisBase: 198
# ERROR:func_adl_xAOD.common.local_dataset:  -- Looking for pthread.h
# ERROR:func_adl_xAOD.common.local_dataset:  -- Looking for pthread.h - found
# ERROR:func_adl_xAOD.common.local_dataset:  -- Performing Test CMAKE_HAVE_LIBC_PTHREAD
# ERROR:func_adl_xAOD.common.local_dataset:  -- Performing Test CMAKE_HAVE_LIBC_PTHREAD - Failed
# ERROR:func_adl_xAOD.common.local_dataset:  -- Check if compiler accepts -pthread
# ERROR:func_adl_xAOD.common.local_dataset:  -- Check if compiler accepts -pthread - yes
# ERROR:func_adl_xAOD.common.local_dataset:  -- Found Threads: TRUE
# ERROR:func_adl_xAOD.common.local_dataset:  -- Configuring ATLAS project with name "UserAnalysis" and version "1.0.0"
# ERROR:func_adl_xAOD.common.local_dataset:  -- Using build type: RelWithDebInfo
# ERROR:func_adl_xAOD.common.local_dataset:  -- Using platform name: x86_64-centos7-gcc8-opt
# ERROR:func_adl_xAOD.common.local_dataset:  -- Cleaning stale files from build area
# ERROR:func_adl_xAOD.common.local_dataset:  -- Unit tests will be built by default
# ERROR:func_adl_xAOD.common.local_dataset:  -- Found 1 package(s)
# ERROR:func_adl_xAOD.common.local_dataset:  -- Considering package 1 / 1
# ERROR:func_adl_xAOD.common.local_dataset:  -- No package filtering rules read
# ERROR:func_adl_xAOD.common.local_dataset:  -- Configuring the build of package: analysis
# ERROR:func_adl_xAOD.common.local_dataset:  -- Number of packages configured: 1
# ERROR:func_adl_xAOD.common.local_dataset:  -- Time for package configuration: 0 seconds
# ERROR:func_adl_xAOD.common.local_dataset:  -- Including the packages from project AnalysisBase - 21.2.231...
# ERROR:func_adl_xAOD.common.local_dataset:  -- Including the packages from project AnalysisBaseExternals - 21.2.231...
# ERROR:func_adl_xAOD.common.local_dataset:  -- Generated file: /workdir/rel/build/x86_64-centos7-gcc8-opt/packages.txt
# ERROR:func_adl_xAOD.common.local_dataset:  -- Generated file: /workdir/rel/build/x86_64-centos7-gcc8-opt/compilers.txt
# ERROR:func_adl_xAOD.common.local_dataset:  -- Generated file: /workdir/rel/build/x86_64-centos7-gcc8-opt/ReleaseData
# ERROR:func_adl_xAOD.common.local_dataset:  -- Generating external environment configuration
# ERROR:func_adl_xAOD.common.local_dataset:  -- Writing runtime environment to file: /workdir/rel/build/x86_64-centos7-gcc8-opt/env_setup.sh
# ERROR:func_adl_xAOD.common.local_dataset:  -- Configuring done
# ERROR:func_adl_xAOD.common.local_dataset:  -- Generating done
# ERROR:func_adl_xAOD.common.local_dataset:  -- Build files have been written to: /workdir/rel/build
# ERROR:func_adl_xAOD.common.local_dataset:  Scanning dependencies of target queryDictDictGen
# ERROR:func_adl_xAOD.common.local_dataset:  [ 11%] Generating queryDictReflexDict.cxx
# ERROR:func_adl_xAOD.common.local_dataset:  [ 11%] Built target queryDictDictGen
# ERROR:func_adl_xAOD.common.local_dataset:  [ 22%] Built UserAnalysisRootMapMerge
# ERROR:func_adl_xAOD.common.local_dataset:  [ 22%] Built target UserAnalysisRootMapMerge
# ERROR:func_adl_xAOD.common.local_dataset:  [ 22%] Built target Package_analysis_tests
# ERROR:func_adl_xAOD.common.local_dataset:  [ 22%] Built target atlas_tests
# ERROR:func_adl_xAOD.common.local_dataset:  [ 33%] Building CXX object analysis/CMakeFiles/analysisLib.dir/Root/query.cxx.o
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /workdir/rel/source/analysis/Root/query.cxx: In member function 'virtual StatusCode query::execute()':
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /workdir/rel/source/analysis/Root/query.cxx:99:26: error: invalid use of incomplete type 'const class xAOD::TrackParticle_v1'
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)            if (((*i_obj16)->pt()>500.0))
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                           ^~
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) In file included from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/TrackParticleContainerFwd.h:19,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/versions/Vertex_v1.h:27,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/Vertex.h:12,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/VertexContainer.h:9,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /workdir/rel/source/analysis/Root/query.cxx:5:
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/TrackParticleFwd.h:14:10: note: forward declaration of 'class xAOD::TrackParticle_v1'
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)     class TrackParticle_v1;
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)           ^~~~~~~~~~~~~~~~
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /workdir/rel/source/analysis/Root/query.cxx:103:39: error: invalid use of incomplete type 'const class xAOD::TrackParticle_v1'
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)              _pt19.push_back((*i_obj16)->pt());
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                                        ^~
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) In file included from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/TrackParticleContainerFwd.h:19,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/versions/Vertex_v1.h:27,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/Vertex.h:12,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/VertexContainer.h:9,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /workdir/rel/source/analysis/Root/query.cxx:5:
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/TrackParticleFwd.h:14:10: note: forward declaration of 'class xAOD::TrackParticle_v1'
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)     class TrackParticle_v1;
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)           ^~~~~~~~~~~~~~~~
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /workdir/rel/source/analysis/Root/query.cxx:113:27: error: 'i_obj14' was not declared in this scope
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)      for (auto &&i_obj17 : i_obj14->trackParticleLinks())
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                            ^~~~~~~
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /workdir/rel/source/analysis/Root/query.cxx:113:27: note: suggested alternative: 'i_obj17'
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)      for (auto &&i_obj17 : i_obj14->trackParticleLinks())
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                            ^~~~~~~
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                            i_obj17
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /workdir/rel/source/analysis/Root/query.cxx:127:27: error: 'i_obj14' was not declared in this scope
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)      for (auto &&i_obj18 : i_obj14->trackParticleLinks())
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                            ^~~~~~~
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /workdir/rel/source/analysis/Root/query.cxx:127:27: note: suggested alternative: 'i_obj18'
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)      for (auto &&i_obj18 : i_obj14->trackParticleLinks())
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                            ^~~~~~~
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                            i_obj18
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) In file included from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/DataVector.h:512,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/ConstDataVector.h:68,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/xAODRootAccess/xAODRootAccess/TStore.h:21,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthToolSupport/AsgTools/AsgTools/SgTEvent.icc:14,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthToolSupport/AsgTools/AsgTools/SgTEvent.h:106,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/PhysicsAnalysis/D3PDTools/AnaAlgorithm/AnaAlgorithm/AnaAlgorithm.h:17,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /workdir/rel/source/analysis/analysis/query.h:4,
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)                  from /workdir/rel/source/analysis/Root/query.cxx:1:
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/tools/DVLCast.h: In instantiation of 'static DataModel_detail::DVLCast<DVL, false>::T* DataModel_detail::DVLCast<DVL, false>::cast(U*) [with U = xAOD::IParticle; DVL = DataVector<xAOD::TrackParticle_v1>; DataModel_detail::DVLCast<DVL, false>::T = xAOD::TrackParticle_v1]':
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/DataVector.icc:1968:54:   required from 'static const T* DataVector<T, BASE>::do_cast(typename BASE::PtrVector::value_type) [with T = xAOD::TrackParticle_v1; BASE = DataVector<xAOD::IParticle>; typename BASE::PtrVector::value_type = xAOD::IParticle*]'
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/DataVector.icc:726:17:   required from 'const T* DataVector<T, BASE>::operator[](DataVector<T, BASE>::size_type) const [with T = xAOD::TrackParticle_v1; BASE = DataVector<xAOD::IParticle>; DataVector<T, BASE>::size_type = long unsigned int]'
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthLinksSA/AthLinks/ElementLink.icc:427:35:   required from 'ElementLink<STORABLE>::ElementConstPointer ElementLink<STORABLE>::cptr() const [with STORABLE = DataVector<xAOD::TrackParticle_v1>; ElementLink<STORABLE>::ElementConstPointer = const xAOD::TrackParticle_v1* const*]'
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthLinksSA/AthLinks/ElementLink.icc:389:30:   required from 'ElementLink<STORABLE>::ElementConstReference ElementLink<STORABLE>::operator*() const [with STORABLE = DataVector<xAOD::TrackParticle_v1>; ElementLink<STORABLE>::ElementConstReference = const xAOD::TrackParticle_v1*]'
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /workdir/rel/source/analysis/Root/query.cxx:99:18:   required from here
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/tools/DVLCast.h:78:12: error: invalid static_cast from type 'xAOD::IParticle*' to type 'DataModel_detail::DVLCast<DataVector<xAOD::TrackParticle_v1>, false>::T*' {aka 'xAOD::TrackParticle_v1*'}
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)      return static_cast<T*> (b);
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr)             ^~~~~~~~~~~~~~~~~~~
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) make[2]: *** [analysis/CMakeFiles/analysisLib.dir/Root/query.cxx.o] Error 1
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) make[1]: *** [analysis/CMakeFiles/analysisLib.dir/all] Error 2
# ERROR:func_adl_xAOD.common.local_dataset:  (stderr) make: *** [all] Error 2
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:ATestRun_eljob.py:
# ERROR:func_adl_xAOD.common.local_dataset:  #
# ERROR:func_adl_xAOD.common.local_dataset:  # Read the submission directory as a command line argument. You can
# ERROR:func_adl_xAOD.common.local_dataset:  # extend the list of arguments with your private ones later on.
# ERROR:func_adl_xAOD.common.local_dataset:  # Set up (Py)ROOT.
# ERROR:func_adl_xAOD.common.local_dataset:  import ROOT  # type: ignore
# ERROR:func_adl_xAOD.common.local_dataset:  import optparse
# ERROR:func_adl_xAOD.common.local_dataset:  from AnaAlgorithm.DualUseConfig import createAlgorithm  # type: ignore
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  parser = optparse.OptionParser()
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  ROOT.xAOD.Init().ignore()
# ERROR:func_adl_xAOD.common.local_dataset:  parser.add_option('-s', '--submission-dir', dest='submission_dir',
# ERROR:func_adl_xAOD.common.local_dataset:                    action='store', type='string', default='submitDir',
# ERROR:func_adl_xAOD.common.local_dataset:                    help='Submission directory for EventLoop')
# ERROR:func_adl_xAOD.common.local_dataset:  (options, args) = parser.parse_args()
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # The sample handler is going to load the files form filelist.txt,
# ERROR:func_adl_xAOD.common.local_dataset:  # in this context, it is an embarrassingly easy use of that object.
# ERROR:func_adl_xAOD.common.local_dataset:  sh = ROOT.SH.SampleHandler()
# ERROR:func_adl_xAOD.common.local_dataset:  sh.setMetaString('nc_tree', 'CollectionTree')
# ERROR:func_adl_xAOD.common.local_dataset:  ROOT.SH.readFileList(sh, "ANALYSIS", "filelist.txt")
# ERROR:func_adl_xAOD.common.local_dataset:  sh.printContent()
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Create an EventLoop job.
# ERROR:func_adl_xAOD.common.local_dataset:  job = ROOT.EL.Job()
# ERROR:func_adl_xAOD.common.local_dataset:  job.sampleHandler(sh)
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Create the algorithm's configuration.
# ERROR:func_adl_xAOD.common.local_dataset:  alg = createAlgorithm('query', 'AnalysisAlg')
# ERROR:func_adl_xAOD.common.local_dataset:  # later on we'll add some configuration options for our algorithm that go here
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Add our algorithm to the job
# ERROR:func_adl_xAOD.common.local_dataset:  job.algsAdd(alg)
# ERROR:func_adl_xAOD.common.local_dataset:  job.outputAdd(ROOT.EL.OutputStream('ANALYSIS'))
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Run the job using the direct driver.
# ERROR:func_adl_xAOD.common.local_dataset:  driver = ROOT.EL.DirectDriver()
# ERROR:func_adl_xAOD.common.local_dataset:  driver.submit(job, options.submission_dir)
# ERROR:func_adl_xAOD.common.local_dataset:filelist.txt:
# ERROR:func_adl_xAOD.common.local_dataset:  /data/DAOD_EXOT15.26710706._000001.pool.root.1
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:package_CMakeLists.txt:
# ERROR:func_adl_xAOD.common.local_dataset:  # The name of the package:
# ERROR:func_adl_xAOD.common.local_dataset:  project(analysis VERSION 1.0)
# ERROR:func_adl_xAOD.common.local_dataset:  atlas_subdir (analysis)
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Add the shared library:
# ERROR:func_adl_xAOD.common.local_dataset:  atlas_add_library (analysisLib
# ERROR:func_adl_xAOD.common.local_dataset:    analysis/*.h Root/*.cxx
# ERROR:func_adl_xAOD.common.local_dataset:    PUBLIC_HEADERS analysis
# ERROR:func_adl_xAOD.common.local_dataset:    LINK_LIBRARIES AnaAlgorithmLib xAODTracking )
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  if (XAOD_STANDALONE)
# ERROR:func_adl_xAOD.common.local_dataset:   # Add the dictionary (for AnalysisBase only):
# ERROR:func_adl_xAOD.common.local_dataset:   atlas_add_dictionary (queryDict
# ERROR:func_adl_xAOD.common.local_dataset:    analysis/query.h
# ERROR:func_adl_xAOD.common.local_dataset:    analysis/selection.xml
# ERROR:func_adl_xAOD.common.local_dataset:    LINK_LIBRARIES analysisLib)
# ERROR:func_adl_xAOD.common.local_dataset:  endif ()
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  if (NOT XAOD_STANDALONE)
# ERROR:func_adl_xAOD.common.local_dataset:    # Add a component library for AthAnalysis only:
# ERROR:func_adl_xAOD.common.local_dataset:    atlas_add_component (analysis
# ERROR:func_adl_xAOD.common.local_dataset:      src/components/*.cxx
# ERROR:func_adl_xAOD.common.local_dataset:      LINK_LIBRARIES analysisLib)
# ERROR:func_adl_xAOD.common.local_dataset:  endif ()
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Install files from the package:
# ERROR:func_adl_xAOD.common.local_dataset:  atlas_install_scripts( share/*_eljob.py )
# ERROR:func_adl_xAOD.common.local_dataset:query.cxx:
# ERROR:func_adl_xAOD.common.local_dataset:  #include <analysis/query.h>
# ERROR:func_adl_xAOD.common.local_dataset:  #include "xAODRootAccess/tools/TFileAccessTracer.h"
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  #include "xAODTracking/VertexContainer.h"
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  #include "xAODTracking/versions/Vertex_v1.h"
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  #include <TTree.h>
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  query :: query (const std::string& name,
# ERROR:func_adl_xAOD.common.local_dataset:                                    ISvcLocator *pSvcLocator)
# ERROR:func_adl_xAOD.common.local_dataset:      : EL::AnaAlgorithm (name, pSvcLocator)
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  {
# ERROR:func_adl_xAOD.common.local_dataset:    // Here you put any code for the base initialization of variables,
# ERROR:func_adl_xAOD.common.local_dataset:    // e.g. initialize all pointers to 0.  This is also where you
# ERROR:func_adl_xAOD.common.local_dataset:    // declare all properties for your algorithm.  Note that things like
# ERROR:func_adl_xAOD.common.local_dataset:    // resetting statistics variables or booking histograms should
# ERROR:func_adl_xAOD.common.local_dataset:    // rather go into the initialize() function.
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    // Turn off file access statistics reporting. This is, according to Attila, useful
# ERROR:func_adl_xAOD.common.local_dataset:    // for GRID jobs, but not so much for other jobs. For those of us not located at CERN
# ERROR:func_adl_xAOD.common.local_dataset:    // and for a large amount of data, this can sometimes take a minute.
# ERROR:func_adl_xAOD.common.local_dataset:    // So we get rid of it.
# ERROR:func_adl_xAOD.common.local_dataset:    xAOD::TFileAccessTracer::enableDataSubmission(false);
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  StatusCode query :: initialize ()
# ERROR:func_adl_xAOD.common.local_dataset:  {
# ERROR:func_adl_xAOD.common.local_dataset:    // Here you do everything that needs to be done at the very
# ERROR:func_adl_xAOD.common.local_dataset:    // beginning on each worker node, e.g. create histograms and output
# ERROR:func_adl_xAOD.common.local_dataset:    // trees.  This method gets called before any input files are
# ERROR:func_adl_xAOD.common.local_dataset:    // connected.
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      ANA_CHECK (book (TTree ("atlas_xaod_tree", "My analysis ntuple")));
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      auto myTree = tree ("atlas_xaod_tree");
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      myTree->Branch("pt", &_pt19);
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      myTree->Branch("eta", &_eta20);
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      myTree->Branch("phi", &_phi21);
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    return StatusCode::SUCCESS;
# ERROR:func_adl_xAOD.common.local_dataset:  }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  StatusCode query :: execute ()
# ERROR:func_adl_xAOD.common.local_dataset:  {
# ERROR:func_adl_xAOD.common.local_dataset:    // Here you do everything that needs to be done on every single
# ERROR:func_adl_xAOD.common.local_dataset:    // events, e.g. read input variables, apply cuts, and fill
# ERROR:func_adl_xAOD.common.local_dataset:    // histograms and trees.  This is where most of your actual analysis
# ERROR:func_adl_xAOD.common.local_dataset:    // code will go.
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      const DataVector<xAOD::Vertex_v1>* vertices13;
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      bool is_first15 (true);
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        const DataVector<xAOD::Vertex_v1>* result = 0;
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        ANA_CHECK (evtStore()->retrieve(result, "PrimaryVertices"));
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        vertices13 = result;
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      for (auto &&i_obj14 : *vertices13)
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        if (is_first15)
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:          is_first15 = false;
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:          for (auto &&i_obj16 : i_obj14->trackParticleLinks())
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:          {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:            if (((*i_obj16)->pt()>500.0))
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:            {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:              _pt19.push_back((*i_obj16)->pt());
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:            }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:          }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      for (auto &&i_obj17 : i_obj14->trackParticleLinks())
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        if (((*i_obj17)->pt()>500.0))
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:          _eta20.push_back((*i_obj17)->eta());
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      for (auto &&i_obj18 : i_obj14->trackParticleLinks())
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        if (((*i_obj18)->pt()>500.0))
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        {
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:          _phi21.push_back((*i_obj18)->phi());
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:        }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      tree("atlas_xaod_tree")->Fill();
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      _pt19.clear();
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      _eta20.clear();
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:      _phi21.clear();
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    return StatusCode::SUCCESS;
# ERROR:func_adl_xAOD.common.local_dataset:  }
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  StatusCode query :: finalize ()
# ERROR:func_adl_xAOD.common.local_dataset:  {
# ERROR:func_adl_xAOD.common.local_dataset:    // This method is the mirror image of initialize(), meaning it gets
# ERROR:func_adl_xAOD.common.local_dataset:    // called after the last event has been processed on the worker node
# ERROR:func_adl_xAOD.common.local_dataset:    // and allows you to finish up any objects you created in
# ERROR:func_adl_xAOD.common.local_dataset:    // initialize() before they are written to disk.  This is actually
# ERROR:func_adl_xAOD.common.local_dataset:    // fairly rare, since this happens separately for each worker node.
# ERROR:func_adl_xAOD.common.local_dataset:    // Most of the time you want to do your post-processing on the
# ERROR:func_adl_xAOD.common.local_dataset:    // submission node after all your histogram outputs have been
# ERROR:func_adl_xAOD.common.local_dataset:    // merged.
# ERROR:func_adl_xAOD.common.local_dataset:    return StatusCode::SUCCESS;
# ERROR:func_adl_xAOD.common.local_dataset:  }
# ERROR:func_adl_xAOD.common.local_dataset:query.h:
# ERROR:func_adl_xAOD.common.local_dataset:  #ifndef analysis_query_H
# ERROR:func_adl_xAOD.common.local_dataset:  #define analysis_query_H
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  #include <AnaAlgorithm/AnaAlgorithm.h>
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  class query : public EL::AnaAlgorithm
# ERROR:func_adl_xAOD.common.local_dataset:  {
# ERROR:func_adl_xAOD.common.local_dataset:  public:
# ERROR:func_adl_xAOD.common.local_dataset:    // this is a standard algorithm constructor
# ERROR:func_adl_xAOD.common.local_dataset:    query (const std::string& name, ISvcLocator* pSvcLocator);
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    // these are the functions inherited from Algorithm
# ERROR:func_adl_xAOD.common.local_dataset:    virtual StatusCode initialize () override;
# ERROR:func_adl_xAOD.common.local_dataset:    virtual StatusCode execute () override;
# ERROR:func_adl_xAOD.common.local_dataset:    virtual StatusCode finalize () override;
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  private:
# ERROR:func_adl_xAOD.common.local_dataset:    // Class level variables
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    std::vector<double> _pt19;
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    std::vector<double> _eta20;
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    std::vector<double> _phi21;
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  };
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  #endif
# ERROR:func_adl_xAOD.common.local_dataset:runner.sh:
# ERROR:func_adl_xAOD.common.local_dataset:  #!/bin/env bash
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # If any problem occurs during the running of this script we want to bail and make sure that
# ERROR:func_adl_xAOD.common.local_dataset:  # everyone above us knows what happened.
# ERROR:func_adl_xAOD.common.local_dataset:  set -e
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Meant to be invokved in an ATLAS R22 analysis container.
# ERROR:func_adl_xAOD.common.local_dataset:  # This follows the tutorial from https://atlassoftwaredocs.web.cern.ch/ABtutorial/release_setup/
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Parse the command line arguments. Our defaults
# ERROR:func_adl_xAOD.common.local_dataset:  output_method="cp"
# ERROR:func_adl_xAOD.common.local_dataset:  output_dir="/results"
# ERROR:func_adl_xAOD.common.local_dataset:  input_method="filelist"
# ERROR:func_adl_xAOD.common.local_dataset:  input_file=""
# ERROR:func_adl_xAOD.common.local_dataset:  compile=1
# ERROR:func_adl_xAOD.common.local_dataset:  run=1
# ERROR:func_adl_xAOD.common.local_dataset:  calib_cache="/xaod_calibration_cache"
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  while getopts "d:o:cr" opt; do
# ERROR:func_adl_xAOD.common.local_dataset:      case "$opt" in
# ERROR:func_adl_xAOD.common.local_dataset:      d)
# ERROR:func_adl_xAOD.common.local_dataset:          input_method="cmd"
# ERROR:func_adl_xAOD.common.local_dataset:          input_file=$OPTARG
# ERROR:func_adl_xAOD.common.local_dataset:          ;;
# ERROR:func_adl_xAOD.common.local_dataset:      c)
# ERROR:func_adl_xAOD.common.local_dataset:          run=0
# ERROR:func_adl_xAOD.common.local_dataset:          ;;
# ERROR:func_adl_xAOD.common.local_dataset:      r)
# ERROR:func_adl_xAOD.common.local_dataset:          compile=0
# ERROR:func_adl_xAOD.common.local_dataset:          ;;
# ERROR:func_adl_xAOD.common.local_dataset:      o)
# ERROR:func_adl_xAOD.common.local_dataset:          output_dir=$OPTARG
# ERROR:func_adl_xAOD.common.local_dataset:          ;;
# ERROR:func_adl_xAOD.common.local_dataset:      ?)
# ERROR:func_adl_xAOD.common.local_dataset:          exit 10
# ERROR:func_adl_xAOD.common.local_dataset:      esac
# ERROR:func_adl_xAOD.common.local_dataset:  done
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # If there are any arguments left over, then very bad things have happened.
# ERROR:func_adl_xAOD.common.local_dataset:  shift $((OPTIND-1))
# ERROR:func_adl_xAOD.common.local_dataset:  if [ $# != 0 ]; then
# ERROR:func_adl_xAOD.common.local_dataset:    echo "Extra arguments on the command line $@"
# ERROR:func_adl_xAOD.common.local_dataset:    exit 1
# ERROR:func_adl_xAOD.common.local_dataset:  fi
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Setup and config
# ERROR:func_adl_xAOD.common.local_dataset:  source /home/atlas/release_setup.sh
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Remember where we are and the script location.
# ERROR:func_adl_xAOD.common.local_dataset:  DIR="$( cd "$( dirname "${BASH_SOURCE[0]}" )" >/dev/null 2>&1 && pwd )"
# ERROR:func_adl_xAOD.common.local_dataset:  local=`pwd`
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Create a release directory
# ERROR:func_adl_xAOD.common.local_dataset:  if [ $compile = 1 ]; then
# ERROR:func_adl_xAOD.common.local_dataset:     mkdir rel
# ERROR:func_adl_xAOD.common.local_dataset:     cd rel
# ERROR:func_adl_xAOD.common.local_dataset:     mkdir source
# ERROR:func_adl_xAOD.common.local_dataset:     mkdir build
# ERROR:func_adl_xAOD.common.local_dataset:     mkdir run
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Create cmake infrastructure
# ERROR:func_adl_xAOD.common.local_dataset:     cat > source/CMakeLists.txt << 'EOF'
# ERROR:func_adl_xAOD.common.local_dataset:  #
# ERROR:func_adl_xAOD.common.local_dataset:  # Project configuration for UserAnalysis.
# ERROR:func_adl_xAOD.common.local_dataset:  #
# ERROR:func_adl_xAOD.common.local_dataset:  project(func_adl_ntupler)
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Set the minimum required CMake version:
# ERROR:func_adl_xAOD.common.local_dataset:  cmake_minimum_required( VERSION 3.4 FATAL_ERROR )
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Try to figure out what project is our parent. Just using a hard-coded list
# ERROR:func_adl_xAOD.common.local_dataset:  # of possible project names. Basically the names of all the other
# ERROR:func_adl_xAOD.common.local_dataset:  # sub-directories inside the Projects/ directory in the repository.
# ERROR:func_adl_xAOD.common.local_dataset:  set( _parentProjectNames Athena AthenaP1 AnalysisBase AthAnalysis
# ERROR:func_adl_xAOD.common.local_dataset:     AthSimulation AthDerivation AnalysisTop )
# ERROR:func_adl_xAOD.common.local_dataset:  set( _defaultParentProject AnalysisBase )
# ERROR:func_adl_xAOD.common.local_dataset:  foreach( _pp ${_parentProjectNames} )
# ERROR:func_adl_xAOD.common.local_dataset:     if( NOT "$ENV{${_pp}_DIR}" STREQUAL "" )
# ERROR:func_adl_xAOD.common.local_dataset:        set( _defaultParentProject ${_pp} )
# ERROR:func_adl_xAOD.common.local_dataset:        break()
# ERROR:func_adl_xAOD.common.local_dataset:     endif()
# ERROR:func_adl_xAOD.common.local_dataset:  endforeach()
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Set the parent project name based on the previous findings:
# ERROR:func_adl_xAOD.common.local_dataset:  set( ATLAS_PROJECT ${_defaultParentProject}
# ERROR:func_adl_xAOD.common.local_dataset:     CACHE STRING "The name of the parent project to build against" )
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Clean up:
# ERROR:func_adl_xAOD.common.local_dataset:  unset( _parentProjectNames )
# ERROR:func_adl_xAOD.common.local_dataset:  unset( _defaultParentProject )
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Find the AnalysisBase project. This is what, amongst other things, pulls
# ERROR:func_adl_xAOD.common.local_dataset:  # in the definition of all of the "atlas_" prefixed functions/macros.
# ERROR:func_adl_xAOD.common.local_dataset:  find_package( ${ATLAS_PROJECT} REQUIRED )
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Set up CTest. This makes sure that per-package build log files can be
# ERROR:func_adl_xAOD.common.local_dataset:  # created if the user so chooses.
# ERROR:func_adl_xAOD.common.local_dataset:  atlas_ctest_setup()
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Set up the GitAnalysisTutorial project. With this CMake will look for "packages"
# ERROR:func_adl_xAOD.common.local_dataset:  # in the current repository and all of its submodules, respecting the
# ERROR:func_adl_xAOD.common.local_dataset:  # "package_filters.txt" file, and set up the build of those packages.
# ERROR:func_adl_xAOD.common.local_dataset:  atlas_project( UserAnalysis 1.0.0
# ERROR:func_adl_xAOD.common.local_dataset:     USE ${ATLAS_PROJECT} ${${ATLAS_PROJECT}_VERSION} )
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Set up the runtime environment setup script. This makes sure that the
# ERROR:func_adl_xAOD.common.local_dataset:  # project's "setup.sh" script can set up a fully functional runtime environment,
# ERROR:func_adl_xAOD.common.local_dataset:  # including all the externals that the project uses.
# ERROR:func_adl_xAOD.common.local_dataset:  lcg_generate_env( SH_FILE ${CMAKE_BINARY_DIR}/${ATLAS_PLATFORM}/env_setup.sh )
# ERROR:func_adl_xAOD.common.local_dataset:  install( FILES ${CMAKE_BINARY_DIR}/${ATLAS_PLATFORM}/env_setup.sh
# ERROR:func_adl_xAOD.common.local_dataset:     DESTINATION . )
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Set up CPack. This call makes sure that an RPM or TGZ file can be created
# ERROR:func_adl_xAOD.common.local_dataset:  # from the built project. Used by Panda to send the project to the grid worker
# ERROR:func_adl_xAOD.common.local_dataset:  # nodes.
# ERROR:func_adl_xAOD.common.local_dataset:  atlas_cpack_setup()
# ERROR:func_adl_xAOD.common.local_dataset:  EOF
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:     # Create a package infrastructure
# ERROR:func_adl_xAOD.common.local_dataset:     cd source
# ERROR:func_adl_xAOD.common.local_dataset:     mkdir analysis
# ERROR:func_adl_xAOD.common.local_dataset:     mkdir analysis/analysis
# ERROR:func_adl_xAOD.common.local_dataset:     mkdir analysis/Root
# ERROR:func_adl_xAOD.common.local_dataset:     mkdir analysis/src
# ERROR:func_adl_xAOD.common.local_dataset:     mkdir analysis/src/components
# ERROR:func_adl_xAOD.common.local_dataset:     mkdir analysis/share
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:     # Create the basics for cmake
# ERROR:func_adl_xAOD.common.local_dataset:     cp $DIR/package_CMakeLists.txt analysis/CMakeLists.txt
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:     # Next, copy over the algorithm. The source directory needs to be correctly mounted.
# ERROR:func_adl_xAOD.common.local_dataset:     cp $DIR/query.h analysis/analysis
# ERROR:func_adl_xAOD.common.local_dataset:     cp $DIR/query.cxx analysis/Root
# ERROR:func_adl_xAOD.common.local_dataset:     cp $DIR/ATestRun_eljob.py analysis/share
# ERROR:func_adl_xAOD.common.local_dataset:     chmod +x analysis/share/ATestRun_eljob.py
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:     cat > analysis/analysis/queryDict.h << EOF
# ERROR:func_adl_xAOD.common.local_dataset:  #ifndef analysis_query_DICT_H
# ERROR:func_adl_xAOD.common.local_dataset:  #define analysis_query_DICT_H
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  // This file includes all the header files that you need to create
# ERROR:func_adl_xAOD.common.local_dataset:  // dictionaries for.
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  #include <analysis/query.h>
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  #endif
# ERROR:func_adl_xAOD.common.local_dataset:  EOF
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:     cat > analysis/analysis/selection.xml << EOF
# ERROR:func_adl_xAOD.common.local_dataset:  <lcgdict>
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    <!-- This file contains a list of all classes for which a dictionary
# ERROR:func_adl_xAOD.common.local_dataset:         should be created. -->
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:    <class name="query" />
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  </lcgdict>
# ERROR:func_adl_xAOD.common.local_dataset:  EOF
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:     # Do the build
# ERROR:func_adl_xAOD.common.local_dataset:     cd ../build
# ERROR:func_adl_xAOD.common.local_dataset:     cmake ../source
# ERROR:func_adl_xAOD.common.local_dataset:     make
# ERROR:func_adl_xAOD.common.local_dataset:  else
# ERROR:func_adl_xAOD.common.local_dataset:     cd rel/build
# ERROR:func_adl_xAOD.common.local_dataset:  fi
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:  # Sort out the input file location
# ERROR:func_adl_xAOD.common.local_dataset:  if [ $run = 1 ]; then
# ERROR:func_adl_xAOD.common.local_dataset:     source ${AnalysisBaseExternals_PLATFORM}/setup.sh
# ERROR:func_adl_xAOD.common.local_dataset:     if [ "$input_method" == "filelist" ]; then
# ERROR:func_adl_xAOD.common.local_dataset:        if [ -e $DIR/filelist.txt ]; then
# ERROR:func_adl_xAOD.common.local_dataset:           cp $DIR/filelist.txt .
# ERROR:func_adl_xAOD.common.local_dataset:        else
# ERROR:func_adl_xAOD.common.local_dataset:           cp $local/filelist.txt .
# ERROR:func_adl_xAOD.common.local_dataset:        fi
# ERROR:func_adl_xAOD.common.local_dataset:     elif [ "$input_method" == "cmd" ]; then
# ERROR:func_adl_xAOD.common.local_dataset:        echo $input_file > filelist.txt
# ERROR:func_adl_xAOD.common.local_dataset:     fi
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:     # Do the run
# ERROR:func_adl_xAOD.common.local_dataset:     if [ -e ./bogus ]; then
# ERROR:func_adl_xAOD.common.local_dataset:       rm -rf bogus
# ERROR:func_adl_xAOD.common.local_dataset:     fi
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:     # If there is a calibration path, lets try to use it.
# ERROR:func_adl_xAOD.common.local_dataset:     if [ -e $calib_cache ]; then
# ERROR:func_adl_xAOD.common.local_dataset:        export CALIBPATH=$calib_cache:$CALIBPATH
# ERROR:func_adl_xAOD.common.local_dataset:        sudo -i chmod a+w $calib_cache
# ERROR:func_adl_xAOD.common.local_dataset:        echo "Using calibration cache: $calib_cache"
# ERROR:func_adl_xAOD.common.local_dataset:        echo "Update calibration sources: $CALIBPATH"
# ERROR:func_adl_xAOD.common.local_dataset:     fi
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:     # Finally, run!
# ERROR:func_adl_xAOD.common.local_dataset:     python ../source/analysis/share/ATestRun_eljob.py --submission-dir=bogus
# ERROR:func_adl_xAOD.common.local_dataset:
# ERROR:func_adl_xAOD.common.local_dataset:     # Place the output file where it belongs
# ERROR:func_adl_xAOD.common.local_dataset:     if [ $output_method == "cp" ]; then
# ERROR:func_adl_xAOD.common.local_dataset:        cmd="cp"
# ERROR:func_adl_xAOD.common.local_dataset:        destination=$output_dir
# ERROR:func_adl_xAOD.common.local_dataset:     else
# ERROR:func_adl_xAOD.common.local_dataset:        destination=$1
# ERROR:func_adl_xAOD.common.local_dataset:        cmd="cp"
# ERROR:func_adl_xAOD.common.local_dataset:        if [[ $destination == "root:"* ]]; then
# ERROR:func_adl_xAOD.common.local_dataset:           cmd="xrdcp"
# ERROR:func_adl_xAOD.common.local_dataset:        fi
# ERROR:func_adl_xAOD.common.local_dataset:     fi
# ERROR:func_adl_xAOD.common.local_dataset:     $cmd ./bogus/data-ANALYSIS/ANALYSIS.root $destination
# ERROR:func_adl_xAOD.common.local_dataset:  fi
# ...
#      52     sx._cache.set_inmem(h, result)
#      53 finally:
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\servicex\servicex.py:436, in ServiceXDataset.get_data_awkward_async(self, selection_query, title)
#     429 @functools.wraps(ServiceXABC.get_data_awkward_async, updated=())
#     430 @_wrap_in_memory_sx_cache
#     431 async def get_data_awkward_async(
#     432     self, selection_query: str, title: Optional[str] = None
#     433 ):
#     434     data_format = self._return_types[0]
#     435     return self._converter.combine_awkward(
# --> 436         await self._data_return(
#     437             selection_query,
#     438             lambda f: self._converter.convert_to_awkward(f),
#     439             title,
#     440             data_format=data_format,
#     441         )
#     442     )
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\backoff\_async.py:151, in retry_exception.<locals>.retry(*args, **kwargs)
#     142 details = {
#     143     "target": target,
#     144     "args": args,
#    (...)
#     147     "elapsed": elapsed,
#     148 }
#     150 try:
# --> 151     ret = await target(*args, **kwargs)
#     152 except exception as e:
#     153     giveup_result = await giveup(e)
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\backoff\_async.py:151, in retry_exception.<locals>.retry(*args, **kwargs)
#     142 details = {
#     143     "target": target,
#     144     "args": args,
#    (...)
#     147     "elapsed": elapsed,
#     148 }
#     150 try:
# --> 151     ret = await target(*args, **kwargs)
#     152 except exception as e:
#     153     giveup_result = await giveup(e)
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\servicex\servicex.py:721, in ServiceXDataset._data_return(self, selection_query, converter, title, data_format)
#     687 @on_exception(backoff.constant, ServiceXUnknownRequestID, interval=0.1, max_tries=3)
#     688 @on_exception(
#     689     backoff.constant,
#    (...)
#     699     data_format: str = "root-file",
#     700 ) -> List[Any]:
#     701     """Given a query, return the data, in a unique order, that hold
#     702     the data for the query.
#     703
#    (...)
#     719                             on the converter call.
#     720     """
# --> 721     all_data = {
#     722         f.file: f.data
#     723         async for f in self._stream_return(
#     724             selection_query, title, converter, data_format
#     725         )
#     726     }
#     728     # Finally, we need them in the proper order so we append them
#     729     # all together
#     730     ordered_data = [all_data[k] for k in sorted(all_data.keys())]
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\servicex\servicex.py:721, in <dictcomp>(.0)
#     687 @on_exception(backoff.constant, ServiceXUnknownRequestID, interval=0.1, max_tries=3)
#     688 @on_exception(
#     689     backoff.constant,
#    (...)
#     699     data_format: str = "root-file",
#     700 ) -> List[Any]:
#     701     """Given a query, return the data, in a unique order, that hold
#     702     the data for the query.
#     703
#    (...)
#     719                             on the converter call.
#     720     """
# --> 721     all_data = {
#     722         f.file: f.data
#     723         async for f in self._stream_return(
#     724             selection_query, title, converter, data_format
#     725         )
#     726     }
#     728     # Finally, we need them in the proper order so we append them
#     729     # all together
#     730     ordered_data = [all_data[k] for k in sorted(all_data.keys())]
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\servicex\servicex.py:764, in ServiceXDataset._stream_return(self, selection_query, title, converter, data_format)
#     741 """Given a query, return the data, in the order it arrives back
#     742 converted as appropriate.
#     743
#    (...)
#     757                         on the converter call.
#     758 """
#     759 as_data = (
#     760     StreamInfoData(f.file, await asyncio.ensure_future(converter(f.path)))
#     761     async for f in self._stream_local_files(selection_query, title, data_format)
#     762 )  # type: ignore
# --> 764 async for r in as_data:
#     765     yield r
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\servicex\servicex.py:759, in <genexpr>(.0)
#     734 async def _stream_return(
#     735     self,
#     736     selection_query: str,
#    (...)
#     739     data_format: str = "root-file",
#     740 ) -> AsyncIterator[StreamInfoData]:
#     741     """Given a query, return the data, in the order it arrives back
#     742     converted as appropriate.
#     743
#    (...)
#     757                             on the converter call.
#     758     """
# --> 759     as_data = (
#     760         StreamInfoData(f.file, await asyncio.ensure_future(converter(f.path)))
#     761         async for f in self._stream_local_files(selection_query, title, data_format)
#     762     )  # type: ignore
#     764     async for r in as_data:
#     765         yield r
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\servicex\servicex.py:799, in ServiceXDataset._stream_local_files(self, selection_query, title, data_format)
#     791 # Get all the files
#     792 as_files = (
#     793     f
#     794     async for f in self._get_files(
#     795         selection_query, data_format, notifier, title
#     796     )
#     797 )  # type: ignore
# --> 799 async for name, a_path in as_files:
#     800     yield StreamInfoPath(name, Path(await a_path))
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\servicex\servicex.py:792, in <genexpr>(.0)
#     789 notifier = self._create_notifier(title, True)
#     791 # Get all the files
# --> 792 as_files = (
#     793     f
#     794     async for f in self._get_files(
#     795         selection_query, data_format, notifier, title
#     796     )
#     797 )  # type: ignore
#     799 async for name, a_path in as_files:
#     800     yield StreamInfoPath(name, Path(await a_path))
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\servicex\servicex.py:838, in ServiceXDataset._get_files(self, selection_query, data_format, notifier, title)
#     834 query = self._build_json_query(selection_query, data_format, title)
#     836 async with aiohttp.ClientSession() as client:
#     837     # Get a request id - which might be cached, but if not, submit it.
# --> 838     request_id = await self._get_request_id(client, query)
#     840     # Make sure cache status exists (user could have deleted, see #176)
#     841     if not self._cache.query_status_exists(request_id):
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\servicex\servicex.py:911, in ServiceXDataset._get_request_id(self, client, query)
#     909 request_id = self._cache.lookup_query(query)
#     910 if request_id is None:
# --> 911     request_info = await self._servicex_adaptor.submit_query(client, query)
#     912     request_id = request_info["request_id"]
#     913     self._cache.set_query(query, request_id)
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\func_adl_servicex\local_dataset.py:92, in _sx_local_file_adaptor.submit_query(self, _, json_query)
#      90 query = json_query['selection']
#      91 title = json_query['title'] if 'title' in json_query else ''
# ---> 92 file_list = await self._ds.execute_result_async(
#      93     text_ast_to_python_ast(query).body[0].value,
#      94     title
#      95 )
#      97 self._minio.associate_file(request_id, file_list)
#      99 # Return the info needed from the submit!
#
# File ~\Code\iris-hep\func_adl_xAOD\func_adl_xAOD\common\local_dataset.py:210, in LocalDataset.execute_result_async(self, a, title)
#     202 except python_on_whales.exceptions.DockerException as e:
#     203     self._dump_info(
#     204         logging.ERROR,
#     205         output,
#    (...)
#     208         self._docker_image,
#     209     )
# --> 210     raise e
#     212 # Now that we have run, we can pluck out the result.
#     213 assert isinstance(f_spec.result_rep, cpp_ttree_rep), "Unknown return type"
#
# File ~\Code\iris-hep\func_adl_xAOD\func_adl_xAOD\common\local_dataset.py:189, in LocalDataset.execute_result_async(self, a, title)
#     181 try:
#     182     output_generator = docker.run(
#     183         docker_image,
#     184         [f"/scripts/{f_spec.main_script}"],
#    (...)
#     187         stream=True,
#     188     )
# --> 189     for stream_type, stream_content in output_generator:  # type: ignore
#     190         if stream_type == "stdout":
#     191             output += f"{stream_content.decode()}"
#
# File c:\Users\gordo\Code\atlas\sx_training_fetch\.venv\lib\site-packages\python_on_whales\utils.py:285, in stream_stdout_and_stderr(full_cmd, env)
#     283 exit_code = process.wait()
#     284 if exit_code != 0:
# --> 285     raise DockerException(full_cmd, exit_code, stderr=full_stderr)
#
# DockerException: The docker command executed was `C:\Program Files\Docker\Docker\resources\bin\docker.EXE container run --rm --volume C:\Users\gordo\AppData\Local\Temp\tmpq3rewcto:/scripts:ro --volume C:\Users\gordo\AppData\Local\Temp\tmpq3rewcto:/results:rw --volume C:\Users\gordo\Code\atlas\data:/data/:ro --volume func_adl_atlas_xaod_calibration_cache:/xaod_calibration_cache atlas/analysisbase:21.2.231 /scripts/runner.sh`.
# It returned with code 2
# The content of stdout can be found above the stacktrace (it wasn't captured).
# The content of stderr is '/workdir/rel/source/analysis/Root/query.cxx: In member function 'virtual StatusCode query::execute()':
# /workdir/rel/source/analysis/Root/query.cxx:99:26: error: invalid use of incomplete type 'const class xAOD::TrackParticle_v1'
#            if (((*i_obj16)->pt()>500.0))
#                           ^~
# In file included from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/TrackParticleContainerFwd.h:19,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/versions/Vertex_v1.h:27,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/Vertex.h:12,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/VertexContainer.h:9,
#                  from /workdir/rel/source/analysis/Root/query.cxx:5:
# /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/TrackParticleFwd.h:14:10: note: forward declaration of 'class xAOD::TrackParticle_v1'
#     class TrackParticle_v1;
#           ^~~~~~~~~~~~~~~~
# /workdir/rel/source/analysis/Root/query.cxx:103:39: error: invalid use of incomplete type 'const class xAOD::TrackParticle_v1'
#              _pt19.push_back((*i_obj16)->pt());
#                                        ^~
# In file included from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/TrackParticleContainerFwd.h:19,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/versions/Vertex_v1.h:27,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/Vertex.h:12,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/VertexContainer.h:9,
#                  from /workdir/rel/source/analysis/Root/query.cxx:5:
# /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Event/xAOD/xAODTracking/xAODTracking/TrackParticleFwd.h:14:10: note: forward declaration of 'class xAOD::TrackParticle_v1'
#     class TrackParticle_v1;
#           ^~~~~~~~~~~~~~~~
# /workdir/rel/source/analysis/Root/query.cxx:113:27: error: 'i_obj14' was not declared in this scope
#      for (auto &&i_obj17 : i_obj14->trackParticleLinks())
#                            ^~~~~~~
# /workdir/rel/source/analysis/Root/query.cxx:113:27: note: suggested alternative: 'i_obj17'
#      for (auto &&i_obj17 : i_obj14->trackParticleLinks())
#                            ^~~~~~~
#                            i_obj17
# /workdir/rel/source/analysis/Root/query.cxx:127:27: error: 'i_obj14' was not declared in this scope
#      for (auto &&i_obj18 : i_obj14->trackParticleLinks())
#                            ^~~~~~~
# /workdir/rel/source/analysis/Root/query.cxx:127:27: note: suggested alternative: 'i_obj18'
#      for (auto &&i_obj18 : i_obj14->trackParticleLinks())
#                            ^~~~~~~
#                            i_obj18
# In file included from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/DataVector.h:512,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/ConstDataVector.h:68,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/xAODRootAccess/xAODRootAccess/TStore.h:21,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthToolSupport/AsgTools/AsgTools/SgTEvent.icc:14,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthToolSupport/AsgTools/AsgTools/SgTEvent.h:106,
#                  from /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/PhysicsAnalysis/D3PDTools/AnaAlgorithm/AnaAlgorithm/AnaAlgorithm.h:17,
#                  from /workdir/rel/source/analysis/analysis/query.h:4,
#                  from /workdir/rel/source/analysis/Root/query.cxx:1:
# /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/tools/DVLCast.h: In instantiation of 'static DataModel_detail::DVLCast<DVL, false>::T* DataModel_detail::DVLCast<DVL, false>::cast(U*) [with U = xAOD::IParticle; DVL = DataVector<xAOD::TrackParticle_v1>; DataModel_detail::DVLCast<DVL, false>::T = xAOD::TrackParticle_v1]':
# /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/DataVector.icc:1968:54:   required from 'static const T* DataVector<T, BASE>::do_cast(typename BASE::PtrVector::value_type) [with T = xAOD::TrackParticle_v1; BASE = DataVector<xAOD::IParticle>; typename BASE::PtrVector::value_type = xAOD::IParticle*]'
# /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/DataVector.icc:726:17:   required from 'const T* DataVector<T, BASE>::operator[](DataVector<T, BASE>::size_type) const [with T = xAOD::TrackParticle_v1; BASE = DataVector<xAOD::IParticle>; DataVector<T, BASE>::size_type = long unsigned int]'
# /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthLinksSA/AthLinks/ElementLink.icc:427:35:   required from 'ElementLink<STORABLE>::ElementConstPointer ElementLink<STORABLE>::cptr() const [with STORABLE = DataVector<xAOD::TrackParticle_v1>; ElementLink<STORABLE>::ElementConstPointer = const xAOD::TrackParticle_v1* const*]'
# /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthLinksSA/AthLinks/ElementLink.icc:389:30:   required from 'ElementLink<STORABLE>::ElementConstReference ElementLink<STORABLE>::operator*() const [with STORABLE = DataVector<xAOD::TrackParticle_v1>; ElementLink<STORABLE>::ElementConstReference = const xAOD::TrackParticle_v1*]'
# /workdir/rel/source/analysis/Root/query.cxx:99:18:   required from here
# /usr/AnalysisBase/21.2.231/InstallArea/x86_64-centos7-gcc8-opt/src/Control/AthContainers/AthContainers/tools/DVLCast.h:78:12: error: invalid static_cast from type 'xAOD::IParticle*' to type 'DataModel_detail::DVLCast<DataVector<xAOD::TrackParticle_v1>, false>::T*' {aka 'xAOD::TrackParticle_v1*'}
#      return static_cast<T*> (b);
#             ^~~~~~~~~~~~~~~~~~~
# make[2]: *** [analysis/CMakeFiles/analysisLib.dir/Root/query.cxx.o] Error 1
# make[1]: *** [analysis/CMakeFiles/analysisLib.dir/all] Error 2
# make: *** [all] Error 2
# '

# %%
from func_adl_servicex_xaodr21.xAOD.vertex_v1 import Vertex_v1
help(Vertex_v1)
# Out:
# Help on class Vertex_v1 in module func_adl_servicex_xaodr21.xAOD.vertex_v1:
#
# class Vertex_v1(builtins.object)
#  |  A class
#  |
#  |  Methods defined here:
#  |
#  |  chiSquared(self) -> 'float'
#  |      A method
#  |
#  |  clearDecorations(self) -> 'bool'
#  |      A method
#  |
#  |  covariance(self) -> 'func_adl_servicex_xaodr21.vector_float_.vector_float_'
#  |      A method
#  |
#  |  hasNonConstStore(self) -> 'bool'
#  |      A method
#  |
#  |  hasStore(self) -> 'bool'
#  |      A method
#  |
#  |  index(self) -> 'int'
#  |      A method
#  |
#  |  nNeutralParticles(self) -> 'int'
#  |      A method
#  |
#  |  nTrackParticles(self) -> 'int'
#  |      A method
#  |
#  |  neutralParticle(self, i: 'int') -> 'func_adl_servicex_xaodr21.xAOD.neutralparticle_v1.NeutralParticle_v1'
#  |      A method
#  |
#  |  neutralParticleLinks(self) -> 'func_adl_servicex_xaodr21.vector_elementlink_datavector_xaod_neutralparticle_v1___.vector_ElementLink_DataVector_xAOD_NeutralParticle_v1___'
#  |      A method
#  |
#  |  neutralWeight(self, i: 'int') -> 'float'
#  |      A method
#  |
#  |  neutralWeights(self) -> 'func_adl_servicex_xaodr21.vector_float_.vector_float_'
#  |      A method
#  |
#  |  numberDoF(self) -> 'float'
#  |      A method
#  |
#  |  trackParticle(self, i: 'int') -> 'func_adl_servicex_xaodr21.xAOD.trackparticle_v1.TrackParticle_v1'
#  |      A method
#  |
#  |  trackParticleLinks(self) -> 'func_adl_servicex_xaodr21.vector_elementlink_datavector_xaod_trackparticle_v1___.vector_ElementLink_DataVector_xAOD_TrackParticle_v1___'
#  |      A method
#  |
#  |  trackWeight(self, i: 'int') -> 'float'
#  |      A method
#  |
#  |  trackWeights(self) -> 'func_adl_servicex_xaodr21.vector_float_.vector_float_'
#  |      A method
#  |
#  |  usingPrivateStore(self) -> 'bool'
#  |      A method
#  |
#  |  usingStandaloneStore(self) -> 'bool'
#  |      A method
#  |
#  |  x(self) -> 'float'
#  |      A method
#  |
#  |  y(self) -> 'float'
#  |      A method
#  |
#  |  z(self) -> 'float'
#  |      A method
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  auxdataConst
#  |      A method
#  |
#  |  isAvailable
#  |      A method
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# ## Muon Segments
#
# We need to pull all the muon segments in as well.

# %%
muon_segments_query = (
    ds
    .Select(lambda e: e.MuonSegments("MuonSegments"))
    .Select(lambda e: {
        "x": e.Select(lambda muon: muon.x()),
        "y": e.Select(lambda muon: muon.y()),
        "z": e.Select(lambda muon: muon.z()),
        "px": e.Select(lambda muon: muon.px()),
        "py": e.Select(lambda muon: muon.py()),
        "pz": e.Select(lambda muon: muon.pz()),
        "t0": e.Select(lambda muon: muon.t0()),
        "chiSquared": e.Select(lambda muon: muon.chiSquared()),
    })
)

muon_segments = muon_segments_query.AsAwkwardArray().value()

# %%
muon_segments.compute()
# Out:
# <Array [{x: [792, ...], y: [...], ...}, ...] type='10000 * {x: var * float3...'>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
